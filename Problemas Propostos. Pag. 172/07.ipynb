# %% [markdown]
# <b>Construir o gráfico e encontrar o foco e uma equação da diretriz.</b>

# %% [markdown]
# <b>7. $x^2 - 10y = 0$</b><br><br>
# <b>Arrumando a equação</b><br><br>
# $x^2 = 10y$<br><br>
# $2p = 10$, logo<br><br>
# $p = 5$<br><br><br>
# <b>Calculando o foco</b><br><br>
# $F = \frac{p}{2}$<br><br>
# $F = \frac{5}{2}$<br><br>
# $F(0, \frac{5}{2})$<br><br>
# <b>Calculando a diretriz</b><br><br>
# $D = -\frac{p}{2}$<br><br>
# $D = -\frac{5}{2}$<br><br>
# $V(0,0)$<br><br>
# $D : y = -\frac{5}{2}$<br><br>
# $F(0, \frac{5}{2})$<br><br>

# %% [markdown]
# <b>Gráfico da parábola</b>

# %%
from sympy import *
from sympy.plotting import plot_implicit
x, y = symbols("x y")
plot_implicit(Eq((x-0)**2, 10*(y+0)), (x,-10,10), (y,-10,10),
title=u'Gráfico da parábola', xlabel='x', ylabel='y');
