# %% [markdown]
# <b>Construir o gráfico e encontrar o foco e uma equação da diretriz.</b>

# %% [markdown]
# <b>2. $y^2 = 6x$</b>

# %% [markdown]
# $2p = 6$,<b>logo</b><br><br>
# $p = 3$<br><br><br>
# <b>Calculando o foco</b><br><br>
# $F = \frac{p}{2}$<br><br>
# $F = \frac{3}{2}$<br><br>
# $F(\frac{3}{2},0)$<br><br><br>
# <b>Calculando a diretriz</b><br><br>
# $d = -\frac{p}{2}$<br><br>
# $d = -\frac{3}{2}$<br><br>
# $d : x = - \frac{3}{2}$<br><br>
# $V(0,0)$<br><br>
# $F(\frac{3}{2},0)$

# %% [markdown]
# <b>Gráfico da parábola</b>

# %%
from sympy import *
from sympy.plotting import plot_implicit
x, y = symbols("x y")
plot_implicit(Eq((y-0)**2, 6*(x+0)), (x,-5,10), (y,-10,10),
title=u'Gráfico da parábola', xlabel='x', ylabel='y');
